# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
diamonds = sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds   #  و هنا يعطينا مجموعة البيانات من أولها لأخرها  , أول خطوة نشوف مجموعة البيانات
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamonds.describe() # خاص بالبيانات الرقمية  تحليل وصفي رقمي
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.describe(exclude='number') # تحليل وصفي غير رقمي
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
diamonds.cut.value_counts() # تحليل وصفي طبقته على عمود
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
diamonds.cut.value_counts(normalize=True)          # نطلعا بالنسب المؤية
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
diamonds.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
sns.histplot(data=diamonds, x='price', bins=10); # تحليل متغير واحد

# %%
sns.kdeplot(data=tips, x='total_bill'); # تحليل متغير واحد

# %%
sns.displot(data=tips, x='total_bill'); # البيانات الرقمية

# %%
sns.displot(data=tips, x='total_bill', kind='kde');

# %%
sns.displot(data=tips, x='total_bill', kind='hist'); # عن طريق ال displot نقدر نرسم hist و Kde

# %%
sns.displot(data=tips, x='total_bill', col='sex'); # اضافة خاصية العمود خلتنا نقارن متغير واحد على مستوى اعلى

# %%
sns.displot(data=tips, x='total_bill', kde=True);

# %%
sns.countplot(data=diamonds, x='cut'); # بيانات غير رقمية

# %%
sns.countplot(data=diamonds, x='color');

# %%
plt.pie(tips.smoker.value_counts(), labels=['NOn-smoker', 'smoker'], autopct='%1.2f%%');

# %%
plt.pie(tips.smoker.value_counts(), labels= tips.smoker.value_counts().index, autopct='%1.2f%%'); 
# و هذي الطريقة هي الأفضل لأنها تخليني أتفادى الأخطاء في تحديد التوزيع

# %%
# تحليل متغيرين  العلاقة بين متغير رقمي و رقمي 
sns.lineplot(data=tips, x='size', y='tip'); # نلاحظ علاقة طردية كل ما زاد عدد الأشخاص كل ما زاد البغشيش

# %%
sns.scatterplot(data=tips, x='size', y='tip'); #   اذا ظهر توزيع بشكل أعمدة فغالبا لان المتغير من النوع الفؤوي بالرغم انه رقمي

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip'); # هنا توزعت صح لأن كل المتغيرات رقمية و العلاقة طردية

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#العلاقة بين متغير فئوي و فئوي 
sns.barplot(data=tips, x='day', y='total_bill', hue='sex'); # يسمى كلسترد بار أو سايد باي سايد بار

# %%
sns.histplot(diamonds.sort_values('clarity').reset_index(), x='clarity', hue='cut', alpha=0.7, multiple="dodge");

# %%
# العلاقة بين متغير فئوي و رقمي

sns.barplot(data=diamonds, x='color', y='price');

# %%
sns.swarmplot(data=tips, x='time', y='tip');

# %%
# تحليل العلاقة بين أكثر من متغييرين 
sns.scatterplot(data=tips, x= 'total_bill', y='tip', hue='smoker');

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(data=tips, x= 'time', y='total_bill', hue='sex', kind='bar', col='day');
